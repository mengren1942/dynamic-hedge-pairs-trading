# %%
from pathlib import Path
import sys

repo_root = Path.cwd().parent           # .. from notebooks/
sys.path.insert(0, str(repo_root))      # make the repo importable

import pairs
print(pairs.__file__)
# Out:
# /home/mengren/projects/dynamic-hedge-pairs-trading-main/pairs/__init__.py

# %%
# From notebooks/ → install the package from the repo root (one level up)
# %pip install -e "..[notebooks]"  # or just ".." if you didn’t define the [notebooks] extra
# Out:
# Obtaining file:///home/mengren/projects/dynamic-hedge-pairs-trading-main
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.24 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from pairs-trading==0.1.0) (2.2.5)
# Requirement already satisfied: pandas>=2.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from pairs-trading==0.1.0) (2.3.1)
# Requirement already satisfied: jupyterlab in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from pairs-trading==0.1.0) (4.4.4)
# Requirement already satisfied: matplotlib>=3.7 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from pairs-trading==0.1.0) (3.10.0)
# Requirement already satisfied: tqdm>=4.66 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from pairs-trading==0.1.0) (4.67.1)
# Requirement already satisfied: openbb>=4 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from pairs-trading==0.1.0) (4.4.5)
# Requirement already satisfied: contourpy>=1.0.1 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from matplotlib>=3.7->pairs-trading==0.1.0) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from matplotlib>=3.7->pairs-trading==0.1.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from matplotlib>=3.7->pairs-trading==0.1.0) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from matplotlib>=3.7->pairs-trading==0.1.0) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from matplotlib>=3.7->pairs-trading==0.1.0) (25.0)
# Requirement already satisfied: pillow>=8 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from matplotlib>=3.7->pairs-trading==0.1.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from matplotlib>=3.7->pairs-trading==0.1.0) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from matplotlib>=3.7->pairs-trading==0.1.0) (2.9.0.post0)
# Requirement already satisfied: openbb-benzinga<2.0.0,>=1.4.2 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb>=4->pairs-trading==0.1.0) (1.4.2)
# Requirement already satisfied: openbb-bls<2.0.0,>=1.1.3 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb>=4->pairs-trading==0.1.0) (1.1.3)
# Requirement already satisfied: openbb-cftc<2.0.0,>=1.1.2 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb>=4->pairs-trading==0.1.0) (1.1.2)
# Requirement already satisfied: openbb-commodity<2.0.0,>=1.3.2 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb>=4->pairs-trading==0.1.0) (1.3.2)
# Requirement already satisfied: openbb-core<2.0.0,>=1.4.8 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb>=4->pairs-trading==0.1.0) (1.4.8)
# Requirement already satisfied: openbb-crypto<2.0.0,>=1.4.2 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb>=4->pairs-trading==0.1.0) (1.4.2)
# Requirement already satisfied: openbb-currency<2.0.0,>=1.4.2 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb>=4->pairs-trading==0.1.0) (1.4.2)
# Requirement already satisfied: openbb-derivatives<2.0.0,>=1.4.2 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb>=4->pairs-trading==0.1.0) (1.4.2)
# Requirement already satisfied: openbb-econdb<2.0.0,>=1.3.2 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb>=4->pairs-trading==0.1.0) (1.3.2)
# Requirement already satisfied: openbb-economy<2.0.0,>=1.4.3 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb>=4->pairs-trading==0.1.0) (1.4.3)
# Requirement already satisfied: openbb-equity<2.0.0,>=1.4.2 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb>=4->pairs-trading==0.1.0) (1.4.2)
# Requirement already satisfied: openbb-etf<2.0.0,>=1.4.2 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb>=4->pairs-trading==0.1.0) (1.4.2)
# Requirement already satisfied: openbb-federal-reserve<2.0.0,>=1.4.4 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb>=4->pairs-trading==0.1.0) (1.4.4)
# Requirement already satisfied: openbb-fixedincome<2.0.0,>=1.4.4 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb>=4->pairs-trading==0.1.0) (1.4.4)
# Requirement already satisfied: openbb-fmp<2.0.0,>=1.4.3 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb>=4->pairs-trading==0.1.0) (1.4.3)
# Requirement already satisfied: openbb-fred<2.0.0,>=1.4.5 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb>=4->pairs-trading==0.1.0) (1.4.5)
# Requirement already satisfied: openbb-imf<2.0.0,>=1.1.2 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb>=4->pairs-trading==0.1.0) (1.1.2)
# Requirement already satisfied: openbb-index<2.0.0,>=1.4.2 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb>=4->pairs-trading==0.1.0) (1.4.2)
# Requirement already satisfied: openbb-intrinio<2.0.0,>=1.4.2 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb>=4->pairs-trading==0.1.0) (1.4.2)
# Requirement already satisfied: openbb-news<2.0.0,>=1.4.2 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb>=4->pairs-trading==0.1.0) (1.4.2)
# Requirement already satisfied: openbb-oecd<2.0.0,>=1.4.2 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb>=4->pairs-trading==0.1.0) (1.4.2)
# Requirement already satisfied: openbb-platform-api<2.0.0,>=1.1.11 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb>=4->pairs-trading==0.1.0) (1.1.13)
# Requirement already satisfied: openbb-polygon<2.0.0,>=1.4.2 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb>=4->pairs-trading==0.1.0) (1.4.2)
# Requirement already satisfied: openbb-regulators<2.0.0,>=1.4.3 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb>=4->pairs-trading==0.1.0) (1.4.3)
# Requirement already satisfied: openbb-sec<2.0.0,>=1.4.4 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb>=4->pairs-trading==0.1.0) (1.4.5)
# Requirement already satisfied: openbb-tiingo<2.0.0,>=1.4.2 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb>=4->pairs-trading==0.1.0) (1.4.2)
# Requirement already satisfied: openbb-tradingeconomics<2.0.0,>=1.4.2 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb>=4->pairs-trading==0.1.0) (1.4.2)
# Requirement already satisfied: openbb-us-eia<2.0.0,>=1.1.2 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb>=4->pairs-trading==0.1.0) (1.1.2)
# Requirement already satisfied: openbb-yfinance<2.0.0,>=1.4.7 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb>=4->pairs-trading==0.1.0) (1.4.7)
# Requirement already satisfied: aiohttp<4.0.0,>=3.12.12 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb-core<2.0.0,>=1.4.8->openbb>=4->pairs-trading==0.1.0) (3.12.15)
# Requirement already satisfied: fastapi<0.116,>=0.115 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb-core<2.0.0,>=1.4.8->openbb>=4->pairs-trading==0.1.0) (0.115.14)
# Requirement already satisfied: html5lib<2.0,>=1.1 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb-core<2.0.0,>=1.4.8->openbb>=4->pairs-trading==0.1.0) (1.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb-core<2.0.0,>=1.4.8->openbb>=4->pairs-trading==0.1.0) (8.5.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.1 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb-core<2.0.0,>=1.4.8->openbb>=4->pairs-trading==0.1.0) (2.11.7)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb-core<2.0.0,>=1.4.8->openbb>=4->pairs-trading==0.1.0) (2.10.1)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb-core<2.0.0,>=1.4.8->openbb>=4->pairs-trading==0.1.0) (1.1.1)
# Requirement already satisfied: python-multipart<0.0.21,>=0.0.20 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb-core<2.0.0,>=1.4.8->openbb>=4->pairs-trading==0.1.0) (0.0.20)
# Requirement already satisfied: requests<3.0.0,>=2.32.4 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb-core<2.0.0,>=1.4.8->openbb>=4->pairs-trading==0.1.0) (2.32.4)
# Requirement already satisfied: ruff<0.13,>=0.12 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb-core<2.0.0,>=1.4.8->openbb>=4->pairs-trading==0.1.0) (0.12.9)
# Requirement already satisfied: uuid7<0.2.0,>=0.1.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb-core<2.0.0,>=1.4.8->openbb>=4->pairs-trading==0.1.0) (0.1.0)
# Requirement already satisfied: uvicorn<0.35.0,>=0.34.2 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb-core<2.0.0,>=1.4.8->openbb>=4->pairs-trading==0.1.0) (0.34.3)
# Requirement already satisfied: websockets<16.0,>=15.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb-core<2.0.0,>=1.4.8->openbb>=4->pairs-trading==0.1.0) (15.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.12.12->openbb-core<2.0.0,>=1.4.8->openbb>=4->pairs-trading==0.1.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.12.12->openbb-core<2.0.0,>=1.4.8->openbb>=4->pairs-trading==0.1.0) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.12.12->openbb-core<2.0.0,>=1.4.8->openbb>=4->pairs-trading==0.1.0) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.12.12->openbb-core<2.0.0,>=1.4.8->openbb>=4->pairs-trading==0.1.0) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.12.12->openbb-core<2.0.0,>=1.4.8->openbb>=4->pairs-trading==0.1.0) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.12.12->openbb-core<2.0.0,>=1.4.8->openbb>=4->pairs-trading==0.1.0) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.12.12->openbb-core<2.0.0,>=1.4.8->openbb>=4->pairs-trading==0.1.0) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.12.12->openbb-core<2.0.0,>=1.4.8->openbb>=4->pairs-trading==0.1.0) (1.20.1)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from fastapi<0.116,>=0.115->openbb-core<2.0.0,>=1.4.8->openbb>=4->pairs-trading==0.1.0) (0.46.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from fastapi<0.116,>=0.115->openbb-core<2.0.0,>=1.4.8->openbb>=4->pairs-trading==0.1.0) (4.12.2)
# Requirement already satisfied: six>=1.9 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from html5lib<2.0,>=1.1->openbb-core<2.0.0,>=1.4.8->openbb>=4->pairs-trading==0.1.0) (1.17.0)
# Requirement already satisfied: webencodings in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from html5lib<2.0,>=1.1->openbb-core<2.0.0,>=1.4.8->openbb>=4->pairs-trading==0.1.0) (0.5.1)
# Requirement already satisfied: aiohttp-client-cache<0.12.0,>=0.11.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb-econdb<2.0.0,>=1.3.2->openbb>=4->pairs-trading==0.1.0) (0.11.1)
# Requirement already satisfied: aiosqlite<0.21.0,>=0.20.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb-econdb<2.0.0,>=1.3.2->openbb>=4->pairs-trading==0.1.0) (0.20.0)
# Requirement already satisfied: itsdangerous>=2.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from aiohttp-client-cache<0.12.0,>=0.11.0->openbb-econdb<2.0.0,>=1.3.2->openbb>=4->pairs-trading==0.1.0) (2.2.0)
# Requirement already satisfied: url-normalize<2.0,>=1.4 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from aiohttp-client-cache<0.12.0,>=0.11.0->openbb-econdb<2.0.0,>=1.3.2->openbb>=4->pairs-trading==0.1.0) (1.4.3)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.13.4 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb-federal-reserve<2.0.0,>=1.4.4->openbb>=4->pairs-trading==0.1.0) (4.13.4)
# Requirement already satisfied: soupsieve>1.2 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from beautifulsoup4<5.0.0,>=4.13.4->openbb-federal-reserve<2.0.0,>=1.4.4->openbb>=4->pairs-trading==0.1.0) (2.5)
# Requirement already satisfied: async-lru<3,>=2 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb-imf<2.0.0,>=1.1.2->openbb>=4->pairs-trading==0.1.0) (2.0.5)
# Requirement already satisfied: requests-cache<2.0.0,>=1.1.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb-intrinio<2.0.0,>=1.4.2->openbb>=4->pairs-trading==0.1.0) (1.2.1)
# Requirement already satisfied: defusedxml<0.9.0,>=0.8.0rc2 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb-oecd<2.0.0,>=1.4.2->openbb>=4->pairs-trading==0.1.0) (0.8.0rc2)
# Requirement already satisfied: urllib3>1.26.16 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb-oecd<2.0.0,>=1.4.2->openbb>=4->pairs-trading==0.1.0) (2.5.0)
# Requirement already satisfied: deepdiff in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb-platform-api<2.0.0,>=1.1.11->openbb>=4->pairs-trading==0.1.0) (8.6.0)
# Requirement already satisfied: inscriptis<3.0.0,>=2.5.3 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb-sec<2.0.0,>=1.4.4->openbb>=4->pairs-trading==0.1.0) (2.6.0)
# Requirement already satisfied: lxml<6.0.0,>=5.2.1 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb-sec<2.0.0,>=1.4.4->openbb>=4->pairs-trading==0.1.0) (5.3.0)
# Requirement already satisfied: trafilatura<3.0,>=2.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb-sec<2.0.0,>=1.4.4->openbb>=4->pairs-trading==0.1.0) (2.0.0)
# Requirement already satisfied: xmltodict<0.14.0,>=0.13.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb-sec<2.0.0,>=1.4.4->openbb>=4->pairs-trading==0.1.0) (0.13.0)
# Requirement already satisfied: openpyxl<4.0.0,>=3.1.5 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb-us-eia<2.0.0,>=1.1.2->openbb>=4->pairs-trading==0.1.0) (3.1.5)
# Requirement already satisfied: xlrd<3.0.0,>=2.0.1 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb-us-eia<2.0.0,>=1.1.2->openbb>=4->pairs-trading==0.1.0) (2.0.2)
# Requirement already satisfied: curl-adapter>=1.1.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb-yfinance<2.0.0,>=1.4.7->openbb>=4->pairs-trading==0.1.0) (1.1.0)
# Requirement already satisfied: yfinance==0.2.58 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openbb-yfinance<2.0.0,>=1.4.7->openbb>=4->pairs-trading==0.1.0) (0.2.58)
# Requirement already satisfied: multitasking>=0.0.7 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from yfinance==0.2.58->openbb-yfinance<2.0.0,>=1.4.7->openbb>=4->pairs-trading==0.1.0) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from yfinance==0.2.58->openbb-yfinance<2.0.0,>=1.4.7->openbb>=4->pairs-trading==0.1.0) (4.3.7)
# Requirement already satisfied: pytz>=2022.5 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from yfinance==0.2.58->openbb-yfinance<2.0.0,>=1.4.7->openbb>=4->pairs-trading==0.1.0) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from yfinance==0.2.58->openbb-yfinance<2.0.0,>=1.4.7->openbb>=4->pairs-trading==0.1.0) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from yfinance==0.2.58->openbb-yfinance<2.0.0,>=1.4.7->openbb>=4->pairs-trading==0.1.0) (3.18.2)
# Requirement already satisfied: curl_cffi>=0.7 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from yfinance==0.2.58->openbb-yfinance<2.0.0,>=1.4.7->openbb>=4->pairs-trading==0.1.0) (0.13.0)
# Requirement already satisfied: et-xmlfile in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from openpyxl<4.0.0,>=3.1.5->openbb-us-eia<2.0.0,>=1.1.2->openbb>=4->pairs-trading==0.1.0) (2.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.5.1->openbb-core<2.0.0,>=1.4.8->openbb>=4->pairs-trading==0.1.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.5.1->openbb-core<2.0.0,>=1.4.8->openbb>=4->pairs-trading==0.1.0) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.5.1->openbb-core<2.0.0,>=1.4.8->openbb>=4->pairs-trading==0.1.0) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from requests<3.0.0,>=2.32.4->openbb-core<2.0.0,>=1.4.8->openbb>=4->pairs-trading==0.1.0) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from requests<3.0.0,>=2.32.4->openbb-core<2.0.0,>=1.4.8->openbb>=4->pairs-trading==0.1.0) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from requests<3.0.0,>=2.32.4->openbb-core<2.0.0,>=1.4.8->openbb>=4->pairs-trading==0.1.0) (2025.8.3)
# Requirement already satisfied: cattrs>=22.2 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from requests-cache<2.0.0,>=1.1.0->openbb-intrinio<2.0.0,>=1.4.2->openbb>=4->pairs-trading==0.1.0) (25.1.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from starlette<0.47.0,>=0.40.0->fastapi<0.116,>=0.115->openbb-core<2.0.0,>=1.4.8->openbb>=4->pairs-trading==0.1.0) (4.7.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi<0.116,>=0.115->openbb-core<2.0.0,>=1.4.8->openbb>=4->pairs-trading==0.1.0) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi<0.116,>=0.115->openbb-core<2.0.0,>=1.4.8->openbb>=4->pairs-trading==0.1.0) (1.3.0)
# Requirement already satisfied: courlan>=1.3.2 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.4->openbb>=4->pairs-trading==0.1.0) (1.3.2)
# Requirement already satisfied: htmldate>=1.9.2 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.4->openbb>=4->pairs-trading==0.1.0) (1.9.3)
# Requirement already satisfied: justext>=3.0.1 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.4->openbb>=4->pairs-trading==0.1.0) (3.0.2)
# Requirement already satisfied: click>=7.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from uvicorn<0.35.0,>=0.34.2->openbb-core<2.0.0,>=1.4.8->openbb>=4->pairs-trading==0.1.0) (8.2.1)
# Requirement already satisfied: h11>=0.8 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from uvicorn<0.35.0,>=0.34.2->openbb-core<2.0.0,>=1.4.8->openbb>=4->pairs-trading==0.1.0) (0.16.0)
# Requirement already satisfied: babel>=2.16.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from courlan>=1.3.2->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.4->openbb>=4->pairs-trading==0.1.0) (2.16.0)
# Requirement already satisfied: tld>=0.13 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from courlan>=1.3.2->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.4->openbb>=4->pairs-trading==0.1.0) (0.13.1)
# Requirement already satisfied: pycurl>=7.45.5 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from curl-adapter>=1.1.0->openbb-yfinance<2.0.0,>=1.4.7->openbb>=4->pairs-trading==0.1.0) (7.45.6)
# Requirement already satisfied: brotli in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from curl-adapter>=1.1.0->openbb-yfinance<2.0.0,>=1.4.7->openbb>=4->pairs-trading==0.1.0) (1.0.9)
# Requirement already satisfied: cffi>=1.12.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from curl_cffi>=0.7->yfinance==0.2.58->openbb-yfinance<2.0.0,>=1.4.7->openbb>=4->pairs-trading==0.1.0) (1.17.1)
# Requirement already satisfied: pycparser in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance==0.2.58->openbb-yfinance<2.0.0,>=1.4.7->openbb>=4->pairs-trading==0.1.0) (2.21)
# Requirement already satisfied: dateparser>=1.1.2 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from htmldate>=1.9.2->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.4->openbb>=4->pairs-trading==0.1.0) (1.2.2)
# Requirement already satisfied: regex>=2024.9.11 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from dateparser>=1.1.2->htmldate>=1.9.2->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.4->openbb>=4->pairs-trading==0.1.0) (2025.7.34)
# Requirement already satisfied: tzlocal>=0.2 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from dateparser>=1.1.2->htmldate>=1.9.2->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.4->openbb>=4->pairs-trading==0.1.0) (5.3.1)
# Requirement already satisfied: zipp>=3.20 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from importlib-metadata>=6.8.0->openbb-core<2.0.0,>=1.4.8->openbb>=4->pairs-trading==0.1.0) (3.21.0)
# Requirement already satisfied: lxml-html-clean in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from lxml[html_clean]>=4.4.2->justext>=3.0.1->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.4->openbb>=4->pairs-trading==0.1.0) (0.4.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from pandas>=2.0->pairs-trading==0.1.0) (2025.2)
# Requirement already satisfied: orderly-set<6,>=5.4.1 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from deepdiff->openbb-platform-api<2.0.0,>=1.1.11->openbb>=4->pairs-trading==0.1.0) (5.5.0)
# Requirement already satisfied: httpx>=0.25.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jupyterlab->pairs-trading==0.1.0) (0.28.1)
# Requirement already satisfied: ipykernel>=6.5.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jupyterlab->pairs-trading==0.1.0) (6.30.1)
# Requirement already satisfied: jinja2>=3.0.3 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jupyterlab->pairs-trading==0.1.0) (3.1.6)
# Requirement already satisfied: jupyter-core in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jupyterlab->pairs-trading==0.1.0) (5.8.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jupyterlab->pairs-trading==0.1.0) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jupyterlab->pairs-trading==0.1.0) (2.16.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jupyterlab->pairs-trading==0.1.0) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jupyterlab->pairs-trading==0.1.0) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jupyterlab->pairs-trading==0.1.0) (72.1.0)
# Requirement already satisfied: tomli>=1.2.2 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jupyterlab->pairs-trading==0.1.0) (2.2.1)
# Requirement already satisfied: tornado>=6.2.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jupyterlab->pairs-trading==0.1.0) (6.5.1)
# Requirement already satisfied: traitlets in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jupyterlab->pairs-trading==0.1.0) (5.14.3)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->pairs-trading==0.1.0) (21.3.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->pairs-trading==0.1.0) (8.6.3)
# Requirement already satisfied: jupyter-events>=0.11.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->pairs-trading==0.1.0) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->pairs-trading==0.1.0) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->pairs-trading==0.1.0) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->pairs-trading==0.1.0) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->pairs-trading==0.1.0) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->pairs-trading==0.1.0) (0.21.1)
# Requirement already satisfied: pyzmq>=24 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->pairs-trading==0.1.0) (26.2.0)
# Requirement already satisfied: send2trash>=1.8.2 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->pairs-trading==0.1.0) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->pairs-trading==0.1.0) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->pairs-trading==0.1.0) (1.8.0)
# Requirement already satisfied: json5>=0.9.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->pairs-trading==0.1.0) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->pairs-trading==0.1.0) (4.25.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->pairs-trading==0.1.0) (21.2.0)
# Requirement already satisfied: httpcore==1.* in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab->pairs-trading==0.1.0) (1.0.9)
# Requirement already satisfied: comm>=0.1.1 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab->pairs-trading==0.1.0) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab->pairs-trading==0.1.0) (1.8.11)
# Requirement already satisfied: ipython>=7.23.1 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab->pairs-trading==0.1.0) (8.30.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab->pairs-trading==0.1.0) (0.1.6)
# Requirement already satisfied: nest-asyncio>=1.4 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab->pairs-trading==0.1.0) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab->pairs-trading==0.1.0) (5.9.0)
# Requirement already satisfied: decorator in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab->pairs-trading==0.1.0) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab->pairs-trading==0.1.0) (0.19.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab->pairs-trading==0.1.0) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab->pairs-trading==0.1.0) (2.19.1)
# Requirement already satisfied: stack-data in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab->pairs-trading==0.1.0) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab->pairs-trading==0.1.0) (4.9.0)
# Requirement already satisfied: wcwidth in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab->pairs-trading==0.1.0) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab->pairs-trading==0.1.0) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jinja2>=3.0.3->jupyterlab->pairs-trading==0.1.0) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->pairs-trading==0.1.0) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->pairs-trading==0.1.0) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->pairs-trading==0.1.0) (0.22.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->pairs-trading==0.1.0) (3.2.1)
# Requirement already satisfied: pyyaml>=5.3 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->pairs-trading==0.1.0) (6.0.2)
# Requirement already satisfied: rfc3339-validator in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->pairs-trading==0.1.0) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->pairs-trading==0.1.0) (0.1.1)
# Requirement already satisfied: fqdn in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->pairs-trading==0.1.0) (1.5.1)
# Requirement already satisfied: isoduration in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->pairs-trading==0.1.0) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->pairs-trading==0.1.0) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->pairs-trading==0.1.0) (1.1.0)
# Requirement already satisfied: uri-template in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->pairs-trading==0.1.0) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->pairs-trading==0.1.0) (24.11.1)
# Requirement already satisfied: bleach!=5.0.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->pairs-trading==0.1.0) (6.2.0)
# Requirement already satisfied: jupyterlab-pygments in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->pairs-trading==0.1.0) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->pairs-trading==0.1.0) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->pairs-trading==0.1.0) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->pairs-trading==0.1.0) (1.5.0)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->pairs-trading==0.1.0) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->pairs-trading==0.1.0) (2.20.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab->pairs-trading==0.1.0) (0.7.0)
# Requirement already satisfied: lark>=1.2.2 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->pairs-trading==0.1.0) (1.2.2)
# Requirement already satisfied: arrow>=0.15.0 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->pairs-trading==0.1.0) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->pairs-trading==0.1.0) (2.9.0.20250822)
# Requirement already satisfied: executing in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab->pairs-trading==0.1.0) (0.8.3)
# Requirement already satisfied: asttokens in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab->pairs-trading==0.1.0) (3.0.0)
# Requirement already satisfied: pure-eval in /home/mengren/anaconda3/envs/pairs/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab->pairs-trading==0.1.0) (0.2.2)
# Building wheels for collected packages: pairs-trading
#   Building editable for pairs-trading (pyproject.toml) ... done
#   Created wheel for pairs-trading: filename=pairs_trading-0.1.0-0.editable-py3-none-any.whl size=2975 sha256=fde115b9308299e90ee6defdc4bd0652990746b061178bdd3ead9207d3db3ad1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-w4pxg4lk/wheels/57/27/7a/50dab0174b306d31d8442aa5fad9ad97bd341d756bf5d5b6b1
# Successfully built pairs-trading
# Installing collected packages: pairs-trading
#   Attempting uninstall: pairs-trading
#     Found existing installation: pairs-trading 0.1.0
#     Uninstalling pairs-trading-0.1.0:
#       Successfully uninstalled pairs-trading-0.1.0
# Successfully installed pairs-trading-0.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys, importlib.util
print(sys.executable)
print(importlib.util.find_spec("pairs"))
import pairs
print(pairs.__version__)
print(pairs.__file__)
# Out:
# /home/mengren/anaconda3/envs/pairs/bin/python
# ModuleSpec(name='pairs', loader=<_frozen_importlib_external.SourceFileLoader object at 0x72e7dc243b80>, origin='/home/mengren/projects/dynamic-hedge-pairs-trading-main/pairs/__init__.py', submodule_search_locations=['/home/mengren/projects/dynamic-hedge-pairs-trading-main/pairs'])
# 0+unknown
# /home/mengren/projects/dynamic-hedge-pairs-trading-main/pairs/__init__.py

# %% [markdown]
# # 1. Download historical data using openbb

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# In a notebook under notebooks/
from pairs import load_universe

tickers = load_universe("spx_ndx_combined")  # returns a pandas.Index (UPPERCASE, deduped)
# tickers = load_universe("ndx")
print(len(tickers), tickers[:10].tolist())   # quick peek
# Out:
# 517 ['A', 'AAPL', 'ABBV', 'ABNB', 'ABT', 'ACGL', 'ACN', 'ADBE', 'ADI', 'ADM']

# %%
from pairs import load_prices, download_openbb

# %%
start_date="2020-01-01"
end_date="2025-01-01"

# df, failed = download_openbb(tickers, start_date, end_date, return_failed=True)
df_train, failed = load_prices('openbb', tickers, start_date, end_date, return_failed=True)

# print(df_train.head())
if failed:
    print("No data for:", failed)
# Out:
# ZTS: 100%|██████████| 517/517 [02:20<00:00,  3.69it/s]
# No data for: ['BF.B', 'BRK.B']

# %%
df_train
# Out:
#                          open        high         low       close   volume  \
# ticker datetime
# A      2020-01-02   85.900002   86.349998   85.199997   85.949997  1410500
#        2020-01-03   84.669998   85.330002   84.500000   84.570000  1118300
#        2020-01-06   84.000000   84.820000   83.599998   84.820000  1993200
#        2020-01-07   83.959999   85.260002   83.940002   85.080002  1684700
#        2020-01-08   85.959999   86.470001   85.199997   85.919998  1847600
# ...                       ...         ...         ...         ...      ...
# ZTS    2024-12-24  163.699997  165.039993  162.740005  164.699997  1023600
#        2024-12-26  163.720001  165.789993  163.020004  165.520004  2167200
#        2024-12-27  164.949997  166.529999  163.520004  164.600006  1800100
#        2024-12-30  163.889999  164.050003  161.449997  162.240005  1531400
#        2024-12-31  162.899994  163.750000  161.869995  162.929993  1327400
#
#                    dividend  split_ratio
# ticker datetime
# A      2020-01-02       0.0          NaN
#        2020-01-03       0.0          NaN
#        2020-01-06       0.0          NaN
#        2020-01-07       0.0          NaN
#        2020-01-08       0.0          NaN
# ...                     ...          ...
# ZTS    2024-12-24       0.0          NaN
#        2024-12-26       0.0          NaN
#        2024-12-27       0.0          NaN
#        2024-12-30       0.0          NaN
#        2024-12-31       0.0          NaN
#
# [639611 rows x 7 columns]

# %% [markdown]
# ## 1.1 Pre-filter for Data Quality

# %% [markdown]
# We keep tickers whose coverage matches the global coverage

# %%
import pandas as pd

# infer level names/positions
lvl_names = list(df_train.index.names)
ticker_lvl = 0                                  # you said ticker is first level
time_lvl_name = 'datetime' if 'datetime' in lvl_names else lvl_names[1]

# global time span
full_start = df_train.index.get_level_values(time_lvl_name).min()
full_end   = df_train.index.get_level_values(time_lvl_name).max()

# per-ticker start/end
starts = df_train.groupby(level=ticker_lvl).apply(
    lambda g: g.index.get_level_values(time_lvl_name).min()
)
ends = df_train.groupby(level=ticker_lvl).apply(
    lambda g: g.index.get_level_values(time_lvl_name).max()
)

# tickers whose coverage matches the global coverage
tickers_to_keep = starts[(starts == full_start) & (ends == full_end)].index

# filter df by those tickers
df_filtered = df_train.loc[pd.IndexSlice[tickers_to_keep, :]]

# %% [markdown]
# The original number of tickers, *vs.* the number of tickers matching the global coverage

# %%
len(df_train.index.get_level_values('ticker').unique()), len(df_filtered.index.get_level_values('ticker').unique())
# Out:
# (515, 499)

# %% [markdown]
# Below is the set of tickers whose time coverages are shorter than the global coverage

# %%
set(tickers) - set(df_filtered.index.get_level_values('ticker').unique())
# Out:
# {'ABNB',
#  'APP',
#  'ARM',
#  'BF.B',
#  'BRK.B',
#  'CARR',
#  'CEG',
#  'COIN',
#  'DASH',
#  'EXE',
#  'GEHC',
#  'GEV',
#  'GFS',
#  'KVUE',
#  'OTIS',
#  'PLTR',
#  'SOLV',
#  'VLTO'}

# %% [markdown]
# # 2. Cointegration Screening

# %% [markdown]
# ## 2.1 Initial Cointegration Screening

# %% [markdown]
# Here, we implement the following two cointegration tests
# - Engle-Granger test, and
# - Johansen test

# %%
from pairs import find_cointegrated_pairs_dualgate

summary_dual = find_cointegrated_pairs_dualgate(
    df_filtered,
    alpha_eg=0.05, eg_trend="c",
    alpha_joh=0.05, joh_det_order=0, joh_k_ar_diff=1, joh_stat="trace",
    n_workers=40, chunksize=8, show_progress=True
)

# %%
summary_dual.sample(20)
# Out:
#                      eg_t      eg_p  eg_pass   joh_stat  joh_pass verdict
# ticker1 ticker2
# CPB     ESS     -3.387607  0.043746     True  18.932104      True    pass
# KMI     UBER    -1.550228  0.741432    False  18.304943      True    fail
# ACN     GPC     -1.671882  0.689620    False   6.016127     False    fail
# GIS     MCHP    -2.180672  0.434352    False  11.817926     False    fail
# ETN     YUM     -1.484179  0.767208    False   6.926738     False    fail
# KMX     MSCI    -1.755280  0.651179    False   8.540872     False    fail
# DHR     KMI     -2.752902  0.181131    False  15.005205     False    fail
# IEX     ROL     -2.438798  0.306706    False  14.497920     False    fail
# MET     TFC     -0.972113  0.908010    False   5.583910     False    fail
# BK      TER     -1.327744  0.821207    False  10.110854     False    fail
# HAS     TTD     -2.046265  0.504460    False   9.061577     False    fail
# JBL     PCAR    -3.191564  0.071350    False  12.586330     False    fail
# NCLH    PRU     -5.528251  0.000016     True  28.062721      True    pass
# DELL    LHX     -1.175991  0.864076    False  11.221620     False    fail
# GLW     NI      -1.939530  0.559832    False  11.652563     False    fail
# ADBE    DDOG    -2.393107  0.328127    False  20.543111      True    fail
# COP     EQR     -1.147507  0.871116    False   6.167318     False    fail
# MRK     WRB     -1.833261  0.613430    False   4.254383     False    fail
# JPM     META    -2.909442  0.133330    False  10.911719     False    fail
# DHI     PLD     -0.652332  0.951542    False   6.118965     False    fail

# %%
# summary_dual is what find_cointegrated_pairs_dualgate returns
tmp = summary_dual.copy()
tmp["rank_eg"]  = tmp["eg_p"].rank(method="average", ascending=True)
tmp["rank_joh"] = tmp["joh_stat"].rank(method="average", ascending=False)
# normalize to [0,1] and average
tmp["pre_score"] = 0.5*(tmp["rank_eg"]/tmp["rank_eg"].max()
                      + tmp["rank_joh"]/tmp["rank_joh"].max())
prelim = tmp.sort_values("pre_score", ascending=True)   # lower rank is better
# pick top N (e.g., 2–3× the number you intend to trade)
candidates = prelim.head(200).index.to_list()

# %%
prelim
# Out:
#                      eg_t          eg_p  eg_pass   joh_stat  joh_pass verdict  \
# ticker1 ticker2
# CCL     TTWO    -6.250168  4.597262e-07     True  42.250921      True    pass
# NCLH    TTWO    -6.371451  2.461515e-07     True  39.980485      True    pass
#         NSC     -6.121224  8.850157e-07     True  38.021322      True    pass
#         TRMB    -6.266599  4.226243e-07     True  37.178857      True    pass
# CCL     SHOP    -6.470849  1.466481e-07     True  36.676596      True    pass
# ...                   ...           ...      ...        ...       ...     ...
# AXP     OXY      0.582827  9.931300e-01    False   1.660159     False    fail
# AVGO    MPC      0.806872  9.938628e-01    False   2.467877     False    fail
#         COP      1.076664  1.000000e+00    False   2.797799     False    fail
# AMP     DVN      0.945155  1.000000e+00    False   2.757229     False    fail
# KKR     OXY      0.944967  1.000000e+00    False   2.508216     False    fail
#
#                   rank_eg  rank_joh  pre_score
# ticker1 ticker2
# CCL     TTWO          8.0      13.0   0.000085
# NCLH    TTWO          5.0      23.0   0.000113
#         NSC          12.0      40.0   0.000209
#         TRMB          7.0      52.0   0.000238
# CCL     SHOP          2.0      61.0   0.000254
# ...                   ...       ...        ...
# AXP     OXY      122578.0  124207.0   0.995138
# AVGO    MPC      123018.0  123785.0   0.995217
#         COP      123737.5  123290.0   0.996133
# AMP     DVN      123737.5  123370.0   0.996455
# KKR     OXY      123737.5  123735.0   0.997924
#
# [124251 rows x 9 columns]

# %%
candidates
# Out:
# [('CCL', 'TTWO'),
#  ('NCLH', 'TTWO'),
#  ('NCLH', 'NSC'),
#  ('NCLH', 'TRMB'),
#  ('CCL', 'SHOP'),
#  ('NCLH', 'WDAY'),
#  ('NCLH', 'PDD'),
#  ('NCLH', 'TER'),
#  ('NCLH', 'TXN'),
#  ('NCLH', 'SBUX'),
#  ('NCLH', 'SHOP'),
#  ('ABT', 'NSC'),
#  ('CCL', 'EBAY'),
#  ('NCLH', 'UDR'),
#  ('NCLH', 'TDY'),
#  ('CCL', 'COO'),
#  ('NCLH', 'ZS'),
#  ('NCLH', 'SW'),
#  ('CCL', 'TRMB'),
#  ('CCL', 'MELI'),
#  ('NCLH', 'PPG'),
#  ('NCLH', 'ZBRA'),
#  ('NCLH', 'WEC'),
#  ('CCL', 'ECL'),
#  ('NCLH', 'ROK'),
#  ('CCL', 'EA'),
#  ('CCL', 'CTSH'),
#  ('NCLH', 'TROW'),
#  ('NCLH', 'STT'),
#  ('CCL', 'FDX'),
#  ('CCL', 'TYL'),
#  ('NCLH', 'PNW'),
#  ('NCLH', 'TEL'),
#  ('NCLH', 'NWSA'),
#  ('NCLH', 'VRSN'),
#  ('CCL', 'TER'),
#  ('GM', 'SW'),
#  ('NCLH', 'TEAM'),
#  ('CCL', 'WDAY'),
#  ('NCLH', 'XYZ'),
#  ('CCL', 'GM'),
#  ('NCLH', 'UNP'),
#  ('NCLH', 'NDSN'),
#  ('NCLH', 'PODD'),
#  ('NCLH', 'TTD'),
#  ('CCL', 'PDD'),
#  ('CCL', 'EMN'),
#  ('CCL', 'EXPE'),
#  ('MA', 'PH'),
#  ('NCLH', 'XEL'),
#  ('NCLH', 'TYL'),
#  ('CCL', 'SW'),
#  ('RCL', 'WMT'),
#  ('NCLH', 'POOL'),
#  ('CCL', 'ZBRA'),
#  ('ABT', 'EMN'),
#  ('NCLH', 'UBER'),
#  ('NCLH', 'PCG'),
#  ('BA', 'JKHY'),
#  ('CCL', 'NFLX'),
#  ('CCL', 'CSGP'),
#  ('CCL', 'FFIV'),
#  ('BDX', 'SJM'),
#  ('CCL', 'NWSA'),
#  ('NCLH', 'QCOM'),
#  ('NCLH', 'REG'),
#  ('NCLH', 'ZTS'),
#  ('CCL', 'TXN'),
#  ('CCL', 'IDXX'),
#  ('CCL', 'DLR'),
#  ('NCLH', 'WDC'),
#  ('CCL', 'NSC'),
#  ('BDX', 'VRSN'),
#  ('CCL', 'EQIX'),
#  ('AWK', 'RVTY'),
#  ('NCLH', 'XYL'),
#  ('NCLH', 'RMD'),
#  ('NCLH', 'TECH'),
#  ('CCL', 'GLW'),
#  ('BDX', 'EA'),
#  ('NCLH', 'NEE'),
#  ('CCL', 'DVA'),
#  ('CCL', 'UBER'),
#  ('CCL', 'ZS'),
#  ('NCLH', 'SPGI'),
#  ('CCL', 'TTD'),
#  ('NCLH', 'NXPI'),
#  ('NCLH', 'STE'),
#  ('NCLH', 'ROL'),
#  ('NCLH', 'TMO'),
#  ('CCL', 'HON'),
#  ('CCL', 'TDY'),
#  ('NCLH', 'WY'),
#  ('NCLH', 'NWS'),
#  ('CCL', 'CMCSA'),
#  ('CCL', 'CPB'),
#  ('CCL', 'DD'),
#  ('NCLH', 'VICI'),
#  ('NCLH', 'WST'),
#  ('CCL', 'ROK'),
#  ('CCL', 'KMX'),
#  ('BDX', 'JNJ'),
#  ('CCL', 'TEL'),
#  ('NCLH', 'STZ'),
#  ('NCLH', 'SYY'),
#  ('NCLH', 'TSLA'),
#  ('CCL', 'TEAM'),
#  ('CCL', 'LH'),
#  ('CCL', 'IP'),
#  ('NCLH', 'VTR'),
#  ('CCL', 'CSX'),
#  ('NCLH', 'SWKS'),
#  ('HST', 'MOH'),
#  ('CSX', 'HST'),
#  ('CCL', 'CRM'),
#  ('CCL', 'WEC'),
#  ('NCLH', 'PTC'),
#  ('CCL', 'HOLX'),
#  ('CCL', 'MCHP'),
#  ('NCLH', 'NTRS'),
#  ('CCL', 'ESS'),
#  ('CCL', 'MHK'),
#  ('CCL', 'XYZ'),
#  ('CCL', 'DDOG'),
#  ('NCLH', 'SHW'),
#  ('NCLH', 'RF'),
#  ('CCL', 'SPGI'),
#  ('NCLH', 'SCHW'),
#  ('CCL', 'EVRG'),
#  ('NCLH', 'O'),
#  ('NCLH', 'TGT'),
#  ('HST', 'STZ'),
#  ('LUV', 'PARA'),
#  ('MAR', 'PANW'),
#  ('NCLH', 'NFLX'),
#  ('BDX', 'NFLX'),
#  ('NCLH', 'TXT'),
#  ('CCL', 'NWS'),
#  ('NCLH', 'PNC'),
#  ('NCLH', 'PLD'),
#  ('NCLH', 'STX'),
#  ('BDX', 'T'),
#  ('BDX', 'DLTR'),
#  ('BDX', 'BLK'),
#  ('CCL', 'GRMN'),
#  ('CCL', 'ITW'),
#  ('NCLH', 'ULTA'),
#  ('BLK', 'SYF'),
#  ('NCLH', 'ROP'),
#  ('BDX', 'GDDY'),
#  ('CCL', 'UDR'),
#  ('CTRA', 'VTRS'),
#  ('NCLH', 'SYF'),
#  ('CCL', 'UNP'),
#  ('CCL', 'MAS'),
#  ('CCL', 'QCOM'),
#  ('NCLH', 'YUM'),
#  ('CCL', 'CNC'),
#  ('CCL', 'NDSN'),
#  ('CCL', 'PPG'),
#  ('CCL', 'NXPI'),
#  ('BDX', 'F'),
#  ('NCLH', 'RVTY'),
#  ('CCL', 'CMI'),
#  ('NCLH', 'WTW'),
#  ('NCLH', 'PYPL'),
#  ('BDX', 'EQIX'),
#  ('CCL', 'MU'),
#  ('BDX', 'HSIC'),
#  ('CCL', 'IEX'),
#  ('BDX', 'UPS'),
#  ('BDX', 'ECL'),
#  ('NCLH', 'T'),
#  ('CCL', 'DGX'),
#  ('NCLH', 'USB'),
#  ('NCLH', 'TSCO'),
#  ('NCLH', 'SBAC'),
#  ('AOS', 'ASML'),
#  ('BDX', 'CTRA'),
#  ('BDX', 'ROK'),
#  ('CCL', 'LULU'),
#  ('BDX', 'IPG'),
#  ('NCLH', 'WAT'),
#  ('BDX', 'DLR'),
#  ('NOW', 'RCL'),
#  ('CCL', 'EQR'),
#  ('CCL', 'HD'),
#  ('BDX', 'PFE'),
#  ('NCLH', 'UPS'),
#  ('NCLH', 'ODFL'),
#  ('CCL', 'ZTS'),
#  ('NCLH', 'PRU'),
#  ('BDX', 'GEN'),
#  ('BDX', 'C'),
#  ('CCL', 'CRWD'),
#  ('CCL', 'DPZ'),
#  ('NCLH', 'ZBH'),
#  ('NCLH', 'PAYC'),
#  ('NCLH', 'SJM'),
#  ('CCL', 'CHRW')]

# %% [markdown]
# ## 2.2 Kalman Filtering and Stationarity Tests on Residuals

# %%
from pairs import (
    fit_kalman_hedge,
    summarize_spread_stationarity_joblib,
)

# %% [markdown]
# ### Overview: Dynamic Hedge via Kalman Filter
#
# We model a time-varying hedge ratio between two assets with a linear Gaussian state-space model.
#
# **State (random walk):**
# $$
# \theta_t =
# \begin{bmatrix}
# \beta_t \\ \alpha_t
# \end{bmatrix},
# \qquad
# \theta_t = \theta_{t-1} + w_t
# $$
# where $w_t\sim\mathcal{N}(0, Q)$.
#
# **Observation:**
# $$
# y_t = \alpha_t + \beta_t x_t + v_t,
# \qquad
# v_t\sim\mathcal{N}(0, R).
# $$
#
# **Calibration:**
# Expectation-Maximization (EM) can learn $Q$ (state noise) and $R$ (observation noise).

# %% [markdown]
# ### Terminology
#
# - **In-sample calibration** (often called "training"): learn $Q$, $R$ with EM and estiamte $(\alpha_t, \beta_t)$ on the train window.
# - **Out-of-sample continuation**: continue **filtering** on the test window using the **last train state and learng $Q, R$.
#
# Here, we perform in-sample calibration of a Kalman filter in the cell below.

# %%
# in-sample calibration of a Kalman filter
states_tr, params_tr = fit_kalman_hedge(
    df_train,
    pairs=candidates,
    mode="smooth",
    em_iters=5,          # modest EM to learn Q/R
    q=1e-5,              # slow drift
    n_workers=None,      # all CPUs
    chunksize=100,
    show_progress=True,
    return_params=True,  # ← get (states, params)
)

# %%
summary_stationarity = summarize_spread_stationarity_joblib(states_tr, alpha=0.05, regression="c", 
                                                            chunksize=256, show_progress=True)

# %%
summary_stationarity
# Out:
#                   adf_stat         adf_p  kpss_stat    kpss_p  halflife  \
# ticker1 ticker2
# NCLH    ZBH     -12.473904  3.199744e-23   0.500000  0.041667  0.623353
#         SJM     -11.099366  3.900236e-20   0.500000  0.041667  0.619043
# CCL     TTD     -19.525280  0.000000e+00   0.020838  0.100000  0.836463
#         MCHP    -19.649539  0.000000e+00   0.024466  0.100000  0.760413
#         MU      -17.815055  3.177767e-30   0.026000  0.100000  0.711484
# ...                    ...           ...        ...       ...       ...
# BDX     CTRA     -9.059207  4.611970e-15   0.011067  0.100000  3.717803
# NCLH    PCG      -8.306838  3.883146e-13   0.146621  0.100000  4.290321
# BDX     T        -8.153646  9.547574e-13   0.010921  0.100000  3.155681
#         IPG      -7.836695  6.088293e-12   0.008038  0.100000  3.495079
#         F        -7.600671  2.394057e-11   0.019156  0.100000  8.527319
#
#                  resid_sigma    shapre       verdict
# ticker1 ticker2
# NCLH    ZBH         0.297637 -0.013053  inconclusive
#         SJM         0.293810 -0.025110  inconclusive
# CCL     TTD         0.432391 -0.075808    stationary
#         MCHP        0.387722 -0.033280    stationary
#         MU          0.352354 -0.036968    stationary
# ...                      ...       ...           ...
# BDX     CTRA        5.915594 -0.009693    stationary
# NCLH    PCG         1.818570 -0.259087    stationary
# BDX     T           5.441019  0.002485    stationary
#         IPG         5.584079 -0.004402    stationary
#         F           9.040715 -0.026724    stationary
#
# [200 rows x 8 columns]

# %% [markdown]
# ### Stationarity Test
#
# The test runs, on each pair:
# 1. **ADF (Augmented Dickey-Fuller)** on the residual series $\varepsilon_t$ (aka spread, contained in states_tr from the cell above)
# - adfuller (s, autolag="AIC", regression=regression)
# - Returns adf_stat, adf_p, plus lags/crit (lags/crit not kept in the summary frame).
# 2. **KPSS** on the same series
# - kpss(s, regression=("c" if regression=="c" else "ct"), nlags="auto")
# - Returns kpss_stat, kpss_p.
#
# **Verdict rule** (using alpha, default 0.05):
# - If **ADF rejects** ($p<\alpha$) **and KPSS does not reject** ($p\geq\alpha$) $\to$ "stationary"
# - If **ADF does not reject and KPSS rejects** $\to$ "non-stationary"
# - Otherwise $\to$ "inconclusive"
#
# **Extra diagnostics it computes**
# - **Half-life** (quick AR-style proxy for mean reversion speed): Fits a slope on ($\varepsilon_{t-1}$ and $\Delta\varepsilon_t$, from the residual series) with np.polyfit and uses
# $$
# \mathrm{halflife} \approx -\frac{\ln 2}{\beta}
# $$
# (returns np.nan if unstable or slope is 0).
#
# Here, $\varepsilon_{t-1}$ is the **previous-period residual**. In our setup,
# $$
# \varepsilon_t = P^{(1)}_t - (\alpha_t + \beta_t P^{(2)}_t),
# $$
# where $P^{(1)}$ and $P^{(2)}$ are the two price series
#
# - **Residual sigma**: s.std() on the residual series $\varepsilon_t$.

# %% [markdown]
# ### Composite scoring to rank tradable pairs
#
# The following cell takes the stationarity diagnostics and creates a **single composite score** per pair to rank candidates for trading. The idea is to convert heterogeneous metrics (p-values, half-life, residual scale, Sharpe) into comparable **z-scores**, align their direction (higher = better), and sum them with optional weights.
#
# #### 1) Inputs and safeguards
# - Start from summary_stationarity (ADF/KPSS results, half-life, standard deviation of residual series $\varepsilon_t$, optional sharpe_train) and copy to final_df.
# - Coerce relevant columns to numeric to avoid dtype surprises.
# - Provide a safe fallback for sharpe_train (zeros if the column is missing).
# - **Clip** extreme values to keep transforms well-behaved:
#     - adf_p, kpss_p are clipped to $[10^{-300}, 1]$ so $-\log_{10}(p)$ never hits infinity.
#     - halflife is clipped at 0 so np.log1p(halflife) is defined (the function np.log1p(x) computes np.log(1+x) but is numerically more accurate).
#
# #### 2) Turn each metric into a "higher is better" score
#
# For a series $s$, the z-score is
# $$
# Z(s) = \frac{s-\bar{s}}{\mathrm{std}(s)}.
# $$
# We apply monotone transforms so that **desirable properties map to larger numbers** before z-scoring:
# - **ADF**: smaller $p$ is better $\longrightarrow$ use $-\log_{10}(p_{\mathrm{ADF}})$ then $Z(\cdot)$
# - **KPSS**: larger $p$ is better $\longrightarrow$ use $Z(p_{\mathrm{KPSS}})$.
# - **Half-life**: shorter is better $\longrightarrow$ use $-\log(1+\textrm{half-life})$ then $Z(\cdot)$
# - **Residual sigma** (spread volatility): lower is better $\longrightarrow$ use $-\sigma_{\varepsilon_t}$ then $Z(\cdot)$
# - **Sharpe (train)**: higher is better $\longrightarrow$ use $Z(\textrm{Sharpe})$ (or zeros if missing)
#
# Each component is standardized independently, making the scales comparable even if raw units differ.
#
# #### 3) Optional weighting
#
# A weights dict (default all 1.0) lets you emphasize particular aspects:
# - e.g., put more weight on **half-life** for faster mean-reverters, or on **ADF** for stronger stationarity evidence.
#
# The composite score is the **weighted sum** of component z-scores:
# $$
# \mathrm{score} = \sum_k w_k Z_k.
# $$
#
# #### 4) Optional out-of-sample (OOS) sanity filter
#
# If validation-window $p$-value exist (adf_p_val, kpss_p_val), filter to pairs that remain stationary OOS:
# - keep pairs with $\text{adf\_p\_val}<0.05$ **and** $\text{adf\_p\_val}<0.10$.
#
# #### 5) Ranking
#
# Sort final_df by score (descending) to get ranked, our prioritized list of pairs.
#
# #### Why these choices?
# - **Z-scores** make heterogeneous signals comparable and robust to unit differences.
# - **Monotone transforms** align the directionality (all components "higher is better").
# - **Clipping** avoids degenerate values (e.g., $p=$ due to underflow).
# - **Log transforms** tame long right tails (half-life) and stabilize contributions.
# - **OOS filter**  guards against in-sample overfitting when you have a held-out window.

# %%
# Imports (once per notebook)
import numpy as np
import pandas as pd
from pairs.stats import Z, zscore  # Z is your back-compat alias

final_df = summary_stationarity.copy()

# Ensure numeric dtypes where needed
for col in ["adf_p", "kpss_p", "halflife", "resid_sigma", "sharpe_train"]:
    if col in final_df.columns:
        final_df[col] = pd.to_numeric(final_df[col], errors="coerce")

# Safe Series fallback for sharpe_train
sharpe_series = final_df.get("sharpe_train", pd.Series(0.0, index=final_df.index))

# Stabilize p-values and halflife before transforms
p_adf   = final_df["adf_p"].clip(lower=1e-300, upper=1.0)      # avoid -log10(0)
p_kpss  = final_df["kpss_p"].clip(lower=1e-300, upper=1.0)
hl_safe = final_df["halflife"].clip(lower=0)                    # no negative half-lives

# Build component scores (higher is better for each)
components = {
    "adf":   Z(-np.log10(p_adf)),        # smaller p → larger score
    "kpss":  Z(p_kpss),                  # larger p → larger score
    "hl":    Z(-np.log1p(hl_safe)),      # shorter half-life → larger score
    "sigma": Z(-final_df["resid_sigma"]),# lower residual sigma → larger score
    "sharpe": Z(sharpe_series),          # optional Sharpe (0 if missing)
}

# Optional weights per component (tune as you like)
weights = {"adf":1.0, "kpss":1.0, "hl":1.0, "sigma":1.0, "sharpe":1.0}

# Weighted sum into a single composite score
final_df["score"] = sum(weights[k] * components[k] for k in components)

# Rank by score
ranked = final_df.sort_values("score", ascending=False)
ranked.head(10)
# Out:
#                   adf_stat         adf_p  kpss_stat  kpss_p  halflife  \
# ticker1 ticker2
# CCL     MCHP    -19.649539  0.000000e+00   0.024466     0.1  0.760413
#         TTD     -19.525280  0.000000e+00   0.020838     0.1  0.836463
#         DLR     -15.350619  3.724449e-28   0.192180     0.1  0.588205
#         DPZ     -14.444186  7.275563e-27   0.062955     0.1  0.576630
# NCLH    SBAC    -14.084387  2.792137e-26   0.057300     0.1  0.575059
# CCL     UNP     -16.802344  1.217436e-29   0.042318     0.1  0.631559
#         ROK     -16.984054  8.968501e-30   0.047278     0.1  0.635333
# BDX     EQIX    -12.781407  7.401953e-24   0.199133     0.1  0.495728
# CCL     ESS     -12.303102  7.373947e-23   0.073752     0.1  0.583293
# HST     STZ     -12.902928  4.210871e-24   0.068852     0.1  0.624545
#
#                  resid_sigma    shapre     verdict      score
# ticker1 ticker2
# CCL     MCHP        0.387722 -0.033280  stationary  10.385113
#         TTD         0.432391 -0.075808  stationary  10.166473
#         DLR         0.231087 -0.039474  stationary   1.197008
#         DPZ         0.239233 -0.025465  stationary   1.177082
# NCLH    SBAC        0.228428 -0.021710  stationary   1.168424
# CCL     UNP         0.238197 -0.019143  stationary   1.126467
#         ROK         0.238337 -0.019329  stationary   1.120946
# BDX     EQIX        0.529830 -0.007558  stationary   1.089944
# CCL     ESS         0.213250 -0.025608  stationary   1.034051
# HST     STZ         0.128600 -0.018348  stationary   1.026907

# %% [markdown]
# - Kalman filtering allows us to obtain the residual series for each pair.
# - Several measures of stationarity of the residual series have been computed above.
# - A score has been computed for each pair, which takes the stationarity diagnostics and creates a **single composite score** per pair to rank candidates for trading. The score converts heterogeneous metrics (p-values, half-life, residual scale, Sharpe) into comparable **z-scores**, thus aligning their direction (higher = better).
# - We select robust pairs based on a plot of the score. The cutoff is set at the elbow of the curve.

# %%
ranked['score'].plot(figsize=(12, 6), grid=True)
# Out:
# <Axes: xlabel='ticker1,ticker2'>

# %% [markdown]
# From the figure above, the elbow of the curve can be estimated to be around -3.

# %%
ranked_positive = ranked[ranked["score"] > -3]
robust_pairs = ranked_positive.index

# %%
len(candidates), len(robust_pairs)
# Out:
# (200, 187)

# %% [markdown]
# #### Select a pair from among the ones meeting the threshold

# %%
import random
(ticker1, ticker2) = robust_pairs[random.randint(0, len(ranked_positive)-1)]
# (ticker1, ticker2) = robust_pairs[0]
print('Pairs:', ticker1, ticker2)
# Out:
# Pairs: CCL GM

# %% [markdown]
# # 3. Generate Trading Signals

# %% [markdown]
# ## 3.1  Extract Kalmal filter states for the selected pair & reshape prices to wide format

# %% [markdown]
# - df_kf = states_tr[(ticker1, ticker2)]
#
#     Pull the Kalman output for the chosen pair from the training window.
#
#     This DataFrame has time index and columns such as:
#     - alpha, beta - time-varying intercept and hedge ratio
#     - y_hat - fitted $\hat{y}_t=\alpha_t+\beta_t x_t$
#     - resid - residual (aka spread) $\varepsilon_t = y_t - \hat{y}_t$
#
# - prices = df_filtered.pivot_table(...)
#     Convert the long, MultiIndex prices into a wide matrix:
#         - Index: datetime
#         - Columns: ticker
#         - Values: close
#
#     This makes it easy to access leg prices side-by-side, e.g. prices[[ticker1, ticker2]], and to join them with df_kf for signal generation or hedged-return calculations.

# %%
df_kf = states_tr[(ticker1, ticker2)]
prices = df_filtered.pivot_table(
    index=df_filtered.index.get_level_values('datetime'), 
    columns=df_filtered.index.get_level_values('ticker'), values='close'
)

# %% [markdown]
# ## Build a pair-aligned frame: leg prices + Kalman fields
#
# This cell constructs a **single DataFrame** with the two leg prices and the key Kalman outputs:
#
# - P1 / P2: spot prices for ticker1 and ticker2 pulled from the wide prices matrix.
# - beta / resid: time-varying hedge ratio and residual (spread) from df_kf.

# %%
df_pair = pd.DataFrame({
    'P1': prices[ticker1],
    'P2': prices[ticker2]
}).join(df_kf[['beta', 'resid']])

# %% [markdown]
# ## 3.2 Generate trading signals

# %%
from pairs.strategies import generate_pair_signals

signals = generate_pair_signals(
    df_pair,
    z_method="robust",
    z_entry=2.0, z_exit=0.5, z_stop=4.0,
    capital_per_pair=10_000,
    max_hold_bars=None,            # set like 3*estimate_halflife(df_pair['resid'])
    cooldown_bars=0
)

# %%
signals
# Out:
#                    z  pos   n1   n2  entry   exit   stop
# datetime
# 2020-01-02       NaN    0  0.0  0.0  False  False  False
# 2020-01-03       NaN    0  0.0  0.0  False  False  False
# 2020-01-06       NaN    0  0.0  0.0  False  False  False
# 2020-01-07       NaN    0  0.0  0.0  False  False  False
# 2020-01-08       NaN    0  0.0  0.0  False  False  False
# ...              ...  ...  ...  ...    ...    ...    ...
# 2024-12-24 -0.076440    0  0.0  0.0  False   True  False
# 2024-12-26 -0.149573    0  0.0  0.0  False  False  False
# 2024-12-27 -0.921285    0  0.0  0.0  False  False  False
# 2024-12-30  0.049232    0  0.0  0.0  False  False  False
# 2024-12-31  0.254934    0  0.0  0.0  False  False  False
#
# [1258 rows x 7 columns]

# %% [markdown]
# # 3.3 Visualize trading signals and compute performance metrics of strategy on training data

# %% [markdown]
# ### 3.3.1 Plot trading signals

# %%
from pairs import plot_pair_legs_with_trades

# %%
# df_pair: has P1,P2 columns (and optionally beta,y_hat)
# signals: from generate_pair_signals(...), has z,pos,n1,n2,entry,exit,stop

plot_pair_legs_with_trades(
    df_pair, signals,
    label1=ticker1, label2=ticker2,
    normalize=False, # base_value=100,
    shade_positions=True,
    size_scale=0.004,   # tweak to taste based on your notional levels
    min_marker=20, max_marker=220
)
# Out:
# (<Figure size 1300x800 with 2 Axes>,
#  (<Axes: ylabel='Price'>,
#   <Axes: title={'center': 'Trades superimposed on each leg • CCL (top), GM (bottom)'}, ylabel='Price'>))

# %% [markdown]
# ### 3.3.2 Compute performance metrics of strategy on training data

# %%
from pairs import evaluate_pair_signals

# %%
# df_pair has P1,P2; signals are your executed outputs (with next-bar logic)
daily, trades, summary = evaluate_pair_signals(
    df_pair, signals,
    cost_bps=1, fee_per_share_1=0.0, fee_per_share_2=0.0,
    borrow_bps_per_year=50,
    days_per_year=252,          # borrow accrual basis
    bars_per_year=252       # 390*252 for 1-min RTH scaling
)


print(pd.Series(summary))
# daily[['pnl_net','equity','drawdown_pct']].tail()
# trades.head()
# Out:
# start                       2020-01-02 00:00:00
# end                         2024-12-31 00:00:00
# bars                                       1258
# capital_base                       10035.403905
# gross_pnl                          17764.929145
# net_pnl                            17618.131803
# ann_return                             0.407209
# sharpe                                 2.478888
# max_drawdown                         965.791117
# max_drawdown_pct                       0.064459
# avg_gross_exposure                  1458.076058
# avg_exposure_utilization               0.998792
# turnover_annualized                   25.658039
# n_trades                                     63
# hit_rate                               0.936508
# avg_win                              305.718142
# avg_loss                             -89.213676
# profit_factor                         50.545418
# avg_hold_bars                          2.904762
# med_hold_bars                               2.0
# ann_vol                                0.141869
# sortino                                5.820994
# gross_return_chain                     5.583469
# net_return_chain                       5.503211
# avg_daily_dollars_traded            1021.780893
# dtype: object

# %% [markdown]
# # 4. Evaulate Strategy performance on out-of-sample data

# %% [markdown]
# ## 4.1 Download or import data for the **selected pair**

# %%
start_test="2025-01-02"
end_test="2025-08-15"

# %%
df_test, failed = load_prices('openbb', [ticker1, ticker2], start_test, end_test, return_failed=True)

print(df_test.head())
if failed:
    print("No data for:", failed)
# Out:
# CCL:   0%|          | 0/2 [00:00<?, ?it/s]
# GM: 100%|██████████| 2/2 [00:00<00:00,  7.06it/s]
#                         open   high        low      close    volume  dividend
# ticker datetime
# CCL    2025-01-02  25.129999  25.40  24.600000  25.010000  26418700       NaN
#        2025-01-03  25.030001  25.10  23.930000  24.379999  20575500       NaN
#        2025-01-06  24.650000  24.74  24.059999  24.129999  20057300       NaN
#        2025-01-07  24.080000  24.17  23.270000  23.840000  23142500       NaN
#        2025-01-08  23.510000  24.27  23.400000  24.180000  18531000       NaN

# %% [markdown]
# ## 4.2 Continue the Kalman filter on out-of-sample (OOS) data

# %% [markdown]
# Use the parameters learned on the training window to *continue* the Kalman filter on the test window, producing OOS paths for $\alpha_t$, $\beta_t$, $\hat{y}_t$ and the residual $\varepsilon_t$ **without** look-ahead.
#
# **What we freeze from training (per pair):**
# - State transition $F$, process noise $Q$, observation noise $R$ - from params_tr.
# - The **last filtered** state at train end: last_state_mean, last_state_cos.
#
#     This carries information into the test window and avoids a diffuse restart.

# %%
# pick the pair you trained
pair = (ticker1, ticker2)

# freeze hyperparameters learned on TRAIN
frozen = {
    "F": params_tr[pair]["F"],
    "Q": params_tr[pair]["Q"],
    "R": params_tr[pair]["R"],
}

# start the new run from the last *filtered* TRAIN state (or use None for diffuse)
last_state = (params_tr[pair]["last_state_mean"], params_tr[pair]["last_state_cov"])

# make sure P1_new, P2_new are aligned and share the same DateTimeIndex
P1_new = df_test.loc[(ticker1,), 'close']
P2_new = df_test.loc[(ticker2,), 'close']

from pairs import filter_kf_on_new

states_te, last_state_te = filter_kf_on_new(
    P1_new, P2_new,
    frozen=frozen,
    last_state=last_state,   # use None to restart diffusely if you *must*
    init_cov=1e6,
    mode="filter"            # "filter" for OOS; "smooth" only for post-hoc analysis
)

# %% [markdown]
# #### Join test states with test prices to prepare signals/evaluation:

# %%
prices_te = df_test.pivot_table(
    index=df_test.index.get_level_values("datetime"),
    columns=df_test.index.get_level_values("ticker"),
    values="close"
)
df_pair_te = states_te.join(
    prices_te[[ticker1, ticker2]].rename(columns={ticker1:"P1", ticker2:"P2"}),
    how="inner"
)

# %% [markdown]
# #### Generate trading signals on out-of-sample (OOS) data

# %%
from pairs.strategies import generate_pair_signals

signals_te = generate_pair_signals(
    df_pair_te,
    z_method="robust",
    z_entry=2.0, z_exit=0.5, z_stop=4.0,
    capital_per_pair=10_000,
    max_hold_bars=None,            # set like 3*estimate_halflife(df_pair['resid'])
    cooldown_bars=0
)

# %% [markdown]
# ## 4.3 Plot trading signals on out-of-sample data

# %%
plot_pair_legs_with_trades(
    df_pair_te, signals_te,
    label1=ticker1, label2=ticker2,
    normalize=False, # base_value=100,
    shade_positions=True,
    size_scale=0.004,   # tweak to taste based on your notional levels
    min_marker=20, max_marker=220
)
# Out:
# (<Figure size 1300x800 with 2 Axes>,
#  (<Axes: ylabel='Price'>,
#   <Axes: title={'center': 'Trades superimposed on each leg • CCL (top), GM (bottom)'}, ylabel='Price'>))

# %% [markdown]
# ## 4.4 Evaluate strategy performance on out-of-sample data

# %%
# df_pair has P1,P2; signals are your executed outputs (with next-bar logic)
daily, trades, summary = evaluate_pair_signals(
    df_pair_te, signals_te,
    cost_bps=1, fee_per_share_1=0.0, fee_per_share_2=0.0,
    borrow_bps_per_year=50,
    days_per_year=252,          # borrow accrual basis
    bars_per_year=252       # 390*252 for 1-min RTH scaling
)


print(pd.Series(summary))
# daily[['pnl_net','equity','drawdown_pct']].tail()
# trades.head()
# Out:
# start                       2025-01-02 00:00:00
# end                         2025-08-15 00:00:00
# bars                                        155
# capital_base                       10001.983189
# gross_pnl                            962.748942
# net_pnl                              946.588122
# ann_return                             0.163403
# sharpe                                 2.176082
# max_drawdown                         199.511824
# max_drawdown_pct                       0.018108
# avg_gross_exposure                  1348.561899
# avg_exposure_utilization                0.99517
# turnover_annualized                   23.008621
# n_trades                                      7
# hit_rate                                    1.0
# avg_win                              136.216798
# avg_loss                                    0.0
# profit_factor                               inf
# avg_hold_bars                               3.0
# med_hold_bars                               2.0
# ann_vol                                0.070708
# sortino                                5.380676
# gross_return_chain                     1.099329
# net_return_chain                       1.097563
# avg_daily_dollars_traded             913.221589
# dtype: object
